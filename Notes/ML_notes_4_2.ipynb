# %% [markdown]
# ## Logistic regression:
# a binary classifier

# %%
import numpy as np
from sklearn import datasets
iris = datasets.load_iris()
list(iris.keys())
X = iris["data"]
# y = (iris["target"] == 2).astype(np.int)

from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X, y)                               # train a logistic regression

y_proba = log_reg.predict_proba(X_new)          # X_new is a new instance, predict_proba() will gives the actual probability
y_pred = log_reg.predict(X_new)                 # predict() will gives the predicted class

# 可以在X的取值空间里创建很多点，然后找出某两个点such that两点距离很小，但一个点的预测是0，另一个点的预测是1，然后就找到了这个模型的decision boundary

# %% [markdown]
# ## Softmax regression:
# a multi-class classifier

# %%
from sklearn import datasets
iris = datasets.load_iris()
X = iris["data"][:, (2, 3)]             # 取petal length, petal width为attributes，单独摘取第三列第四列的数据
from sklearn.linear_model import LogisticRegression

softmax_reg = LogisticRegression(multi_class="multinomial",solver="lbfgs", C=10)        # multinomial：告诉模型做softmax regression。solver这个设定的是优化算法求解器不用改。C取值越大模型越更加拟合训练数据，取值越小越容易泛化(模型更加简单)
softmax_reg.fit(X, y)
softmax_reg.predict([[5, 2]])                                                           # 输出predicted class
softmax_reg.predict_proba([[5, 2]])                                                     # 输出每个class的predicted probability
